# %% [markdown]
# # 1) Download the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Downloaded from kaggle
df=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # 2) Load the Dataset

# %%
df=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # 3) Visualizations
# 1) Univariate
# 2) Bivariate
# 3) Multivariate

# %%
#Univariate
df['Date'].plot()
plt.show()
df['Price'].plot()
# Out:
# <Axes: >

# %%
sns.distplot(df['Price'])
plt.show()
sns.distplot(df['number of bedrooms'])
plt.show()
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_24520\2786645256.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# C:\Users\varun\AppData\Local\Temp\ipykernel_24520\2786645256.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#bivariate
plt.scatter(df['number of bedrooms'],df.Price)
plt.show()
sns.lineplot(x=df['Date'],y=df.Price)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
#bivariate-Joinplot
sns.jointplot(x='Date',y='Price',data=df)
plt.show()
sns.jointplot(x='number of bedrooms',y='Price',data=df)

# %%
#Multivariate
sns.pairplot(df)#commented

#Output for paiplot has been attached as an immage in order to avoid file size exceeding 10MB
from matplotlib import image as img
image = img.imread("C:\\Users\\varun\\OneDrive\\Desktop\\pairplot op.png")
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

# %% [markdown]
# # 4)  Perform descriptive statistics on the Dataset

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# # 5) Handle the Missing values

# %%
print(df.isna().sum())
#There is no nan values present in the given dataset so there is no need to replace the missing values
df.isna().any()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...
